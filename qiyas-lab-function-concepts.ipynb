# %%
#function defintion
def my_function():
    print("hello world")

my_function()
# Out:
# hello world

# %%
#default argument
def greet(name,message='Hello'):
    return f"{message}, {name}"

greet('Abraham')
# Out:
# 'Hello, Abraham'

# %%
#Variable-Length Argument

def total(*args):
    return sum(args)

print("sum =",total(1,2,3,4,5))
# Out:
# sum = 15
